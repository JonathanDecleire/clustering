# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn import metrics
from sklearn.metrics import silhouette_score
from kneed import KneeLocator

# %%
# !pip install geopandas
#conda install -c conda-forge kneed

# %%
df = pd.read_csv('chipotle_stores.csv')

# %%
df.head()
# Out:
#      state    location                                    address   latitude  \
# 0  Alabama      Auburn     346 W Magnolia Ave Auburn, AL 36832 US  32.606813
# 1  Alabama  Birmingham      300 20th St S Birmingham, AL 35233 US  33.509721
# 2  Alabama  Birmingham     3220 Morrow Rd Birmingham, AL 35235 US  33.595581
# 3  Alabama  Birmingham   4719 Highway 280 Birmingham, AL 35242 US  33.422582
# 4  Alabama     Cullman  1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134
#
#    longitude
# 0 -85.487328
# 1 -86.802756
# 2 -86.647437
# 3 -86.698279
# 4 -86.841220

# %%
df.shape
# Out:
# (2629, 5)

# %%
states = gpd.read_file('us-states.json')
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
states.head()
# Out:
#    id        name                                           geometry
# 0  AL     Alabama  POLYGON ((-87.35930 35.00118, -85.60667 34.984...
# 1  AK      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2  AZ     Arizona  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 3  AR    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  CA  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
# plt.subplots(figsize=(18,10))
states.plot(figsize=(18,10))
plt.scatter(df["longitude"], df["latitude"],s=0.5, color="r")
plt.xlim([-130,-55])
plt.ylim([25,50])
plt.show()

"""
Create the repository
Install geopandas
Plot the US map
Visualize your data on this map
Plot a dendrogram of your data to help you decide the appropriate clustering resolution
Compare and analyze different clustering methods using intrinsic analysis to decide on a chosen method.
Choose a centroid/address to live
Publish your results to a GitHub page with an explanation of your method.
"""

# conda install -c conda-forge descartes
# Out:
# '\nCreate the repository\nInstall geopandas\nPlot the US map\nVisualize your data on this map\nPlot a dendrogram of your data to help you decide the appropriate clustering resolution\nCompare and analyze different clustering methods using intrinsic analysis to decide on a chosen method.\nChoose a centroid/address to live\nPublish your results to a GitHub page with an explanation of your method.\n'

# %%
df.columns
# Out:
# Index(['state', 'location', 'address', 'latitude', 'longitude'], dtype='object')

# %%
states.columns
# Out:
# Index(['id', 'name', 'geometry'], dtype='object')

# %%
df
# Out:
#              state          location  \
# 0          Alabama            Auburn
# 1          Alabama        Birmingham
# 2          Alabama        Birmingham
# 3          Alabama        Birmingham
# 4          Alabama           Cullman
# ...            ...               ...
# 2624     Wisconsin  Pleasant Prairie
# 2625     Wisconsin         Wauwatosa
# 2626  North Dakota             Fargo
# 2627  North Dakota             Fargo
# 2628       Wyoming          Cheyenne
#
#                                              address   latitude   longitude
# 0             346 W Magnolia Ave Auburn, AL 36832 US  32.606813  -85.487328
# 1              300 20th St S Birmingham, AL 35233 US  33.509721  -86.802756
# 2             3220 Morrow Rd Birmingham, AL 35235 US  33.595581  -86.647437
# 3           4719 Highway 280 Birmingham, AL 35242 US  33.422582  -86.698279
# 4          1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134  -86.841220
# ...                                              ...        ...         ...
# 2624  9370 76th St # B Pleasant Prairie, WI 53158 US  42.565892  -87.921048
# 2625  2711 N Mayfair Rd Ste A Wauwatosa, WI 53222 US  43.067723  -88.048222
# 2626              1204 19th Ave N Fargo, ND 58102 US  46.904247  -96.796618
# 2627               1680 45th St S Fargo, ND 58103 US  46.855337  -96.861416
# 2628      1508 Dell Range Blvd Cheyenne, WY 82009 US  41.160718 -104.805699
#
# [2629 rows x 5 columns]

# %%
import scipy.cluster.hierarchy as sch
X = df.loc[:,['longitude','latitude']]
plt.figure(figsize=(18,10))
dendrogram = sch.dendrogram(sch.linkage(X, method  = "ward"))

plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
#state with high density
df['state'].value_counts()
#let's fix the threshold at 70 by state
# Out:
# California        421
# Texas             226
# Ohio              193
# Florida           177
# New York          160
# Illinois          144
# Virginia          107
# Pennsylvania       96
# Maryland           94
# Arizona            85
# Colorado           79
# Minnesota          71
# New Jersey         69
# North Carolina     65
# Massachusetts      62
# Georgia            61
# Washington         43
# Indiana            40
# Missouri           39
# Michigan           39
# Oregon             32
# Kansas             30
# Nevada             29
# Tennessee          26
# Connecticut        24
# Washington DC      21
# Kentucky           21
# South Carolina     21
# Wisconsin          20
# Alabama            15
# Oklahoma           12
# Utah               11
# Nebraska           10
# Louisiana          10
# Iowa               10
# Rhode Island        9
# Delaware            9
# New Mexico          9
# New Hampshire       8
# West Virginia       6
# Arkansas            6
# Maine               5
# Idaho               4
# Montana             3
# Vermont             2
# Mississippi         2
# North Dakota        2
# Wyoming             1
# Name: state, dtype: int64

# %%
#location with the highest density (above 10 locations)
pd.set_option("display.max_rows", None, "display.max_columns", None)
df_location = df['location'].value_counts().nlargest(40)
df_location
# Out:
# New York            52
# Chicago             36
# Houston             31
# Columbus            22
# Washington DC       21
# Los Angeles         20
# Las Vegas           19
# Dallas              19
# Phoenix             19
# Cincinnati          17
# Brooklyn            16
# Austin              16
# Orlando             16
# Denver              15
# San Diego           15
# Atlanta             15
# San Jose            14
# San Antonio         13
# Charlotte           13
# Aurora              13
# Philadelphia        13
# Kansas City         13
# Sacramento          12
# Springfield         12
# Baltimore           12
# Pittsburgh          11
# Portland            10
# Jacksonville        10
# Tampa               10
# Columbia            10
# Miami               10
# Scottsdale          10
# Richmond             9
# Fort Worth           9
# San Francisco        9
# Minneapolis          9
# Indianapolis         9
# Tucson               9
# Colorado Springs     8
# Lakewood             8
# Name: location, dtype: int64

# %%
# list of locations with more than 10 chepotles
locations = df['location'].value_counts().index.tolist()[:32]
locations
# Out:
# ['New York',
#  'Chicago',
#  'Houston',
#  'Columbus',
#  'Washington DC',
#  'Los Angeles',
#  'Las Vegas',
#  'Dallas',
#  'Phoenix',
#  'Cincinnati',
#  'Brooklyn',
#  'Austin',
#  'Orlando',
#  'Denver',
#  'San Diego',
#  'Atlanta',
#  'San Jose',
#  'San Antonio',
#  'Charlotte',
#  'Aurora',
#  'Philadelphia',
#  'Kansas City',
#  'Sacramento',
#  'Springfield',
#  'Baltimore',
#  'Pittsburgh',
#  'Portland',
#  'Jacksonville',
#  'Tampa',
#  'Columbia',
#  'Miami',
#  'Scottsdale']

# %%
# dataframe with highest density
df_best_location = df.loc[df['location'].isin(locations)]
df_best_location.head(10)
# Out:
#       state location                                            address  \
# 49  Arizona  Phoenix        100 E Camelback Rd 200 Phoenix, AZ 85012 US
# 50  Arizona  Phoenix  11 W Washington St Suite 140 Phoenix, AZ 85003 US
# 51  Arizona  Phoenix        1515 N 7th Ave Ste 120 Phoenix, AZ 85007 US
# 52  Arizona  Phoenix   1660 E Camelback Rd Ste 185 Phoenix, AZ 85016 US
# 53  Arizona  Phoenix    16635 N Tatum Blvd Ste 100 Phoenix, AZ 85032 US
# 54  Arizona  Phoenix        1818 W Bethany Home Rd Phoenix, AZ 85015 US
# 55  Arizona  Phoenix            21001 N Tatum Blvd Phoenix, AZ 85050 US
# 56  Arizona  Phoenix    2415 E Baseline Rd Ste 111 Phoenix, AZ 85042 US
# 57  Arizona  Phoenix          2450 W Bell Rd Ste 5 Phoenix, AZ 85023 US
# 58  Arizona  Phoenix  2470 W Happy Valley Rd Ste 1181 Phoenix, AZ 85...
#
#      latitude   longitude
# 49  33.509660 -112.071679
# 50  33.448061 -112.074456
# 51  33.465598 -112.082381
# 52  33.510375 -112.046220
# 53  33.638185 -111.977387
# 54  33.524380 -112.098686
# 55  33.674753 -111.975275
# 56  33.377257 -112.029873
# 57  33.640373 -112.112279
# 58  33.714657 -112.112572

# %%
import scipy.cluster.hierarchy as sch
X = df_best_location.loc[:,['longitude','latitude']]
plt.figure(figsize=(18,18))
dendrogram = sch.dendrogram(sch.linkage(X, method  = "ward"))

plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## Using KMeans

# %%
#clustering using all the data
from sklearn.cluster import KMeans
# all the data 
y = df[['longitude','latitude']]
# fit a kmeans object to the dataset
km = KMeans(n_clusters=24, init='k-means++')
kmeans = km.fit(y)
# clusters is an attribute of the object
cluster_centers = kmeans.cluster_centers_

# add cluster to dataframe
cluster_labels = pd.Series(kmeans.labels_, name='cluster')
y_clust = y.join(cluster_labels.to_frame())

y_clust.head(10)
# Out:
#    longitude   latitude  cluster
# 0 -85.487328  32.606813        4
# 1 -86.802756  33.509721        4
# 2 -86.647437  33.595581        4
# 3 -86.698279  33.422582        4
# 4 -86.841220  34.154134       23
# 5 -86.803802  33.378958        4
# 6 -86.665720  34.742319       23
# 7 -88.143754  30.675338        4
# 8 -88.224998  30.682731        4
# 9 -86.162253  32.359177        4

# %%
# #set cluster as index
# y_clust.set_index('cluster').sort_index()  ?????

# %%
cluster_centers
# Out:
# array([[ -90.4204563 ,   39.66453686],
#        [-111.95744146,   33.3988663 ],
#        [ -76.97812174,   38.84467438],
#        [-121.67434047,   37.86468298],
#        [ -84.60077719,   33.6211835 ],
#        [ -96.96156472,   33.04753621],
#        [ -87.81478276,   42.01349947],
#        [-122.32331428,   46.34125905],
#        [ -80.42651427,   26.24309957],
#        [-105.04530226,   39.64634512],
#        [ -74.35325503,   40.81101936],
#        [-117.72603948,   34.07870689],
#        [-112.79926856,   42.3569709 ],
#        [ -79.88649789,   35.2010986 ],
#        [ -81.52877049,   41.39285575],
#        [ -95.07335207,   38.7298526 ],
#        [ -84.18959507,   39.71666883],
#        [ -71.50591636,   42.40810932],
#        [ -93.39590886,   44.91323114],
#        [ -98.03602302,   29.70795566],
#        [ -81.95281663,   28.65897324],
#        [-105.05868857,   33.36420883],
#        [ -94.86595037,   29.99220609],
#        [ -87.46911024,   35.6229462 ]])

# %%
 #cluster_labels  # has been add as the cluster column

# %%
y_clust.head(16)
# Out:
#      longitude   latitude  cluster
# 0   -85.487328  32.606813        4
# 1   -86.802756  33.509721        4
# 2   -86.647437  33.595581        4
# 3   -86.698279  33.422582        4
# 4   -86.841220  34.154134       23
# 5   -86.803802  33.378958        4
# 6   -86.665720  34.742319       23
# 7   -88.143754  30.675338        4
# 8   -88.224998  30.682731        4
# 9   -86.162253  32.359177        4
# 10  -85.404479  32.616809        4
# 11  -86.391343  32.459169        4
# 12  -87.553621  33.210669       23
# 13  -87.527042  33.196755       23
# 14  -86.788285  33.439069        4
# 15 -112.273194  33.464377        1

# %%
metric_1 = np.array([y_clust[y_clust['cluster']==12][['longitude','latitude']]])
metric_1
# Out:
# array([[[-116.2823    ,   43.606686  ],
#         [-116.20309364,   43.61266805],
#         [-116.28303341,   43.67126092],
#         [-116.3537875 ,   43.6241636 ],
#         [-108.55686034,   45.78437259],
#         [-111.06287481,   45.6797178 ],
#         [-114.0400163 ,   46.8921789 ],
#         [-111.85151519,   40.62565661],
#         [-111.9847553 ,   41.0887238 ],
#         [-111.888371  ,   40.4320963 ],
#         [-111.8878451 ,   40.6597349 ],
#         [-111.67868004,   40.27351682],
#         [-111.9994683 ,   41.1782739 ],
#         [-111.8620372 ,   40.7255254 ],
#         [-111.86985   ,   40.76048   ],
#         [-111.8904488 ,   40.5626127 ],
#         [-111.89262856,   40.89083706]]])

# %%
states.boundary.plot(figsize=(20,20))
g = sns.scatterplot(x='longitude', y='latitude', data=y_clust, hue='cluster', palette='husl')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
plt.xlim([-130,-55])
plt.ylim([25,50])
plt.show()

#sns.lmplot(x='longitude', y='latitude', height=5, data=y,fit_reg=False, hue='cluster')

# %%
# select the one with the minimum distance to the

# %%
# z = df.loc[df['location'] == 'New York']
# z[['longitude','latitude']].head(10)

# %%
def distance_to_other_locations(y):   #using Eucledian distance 

    '''
    Given a Point, the function sums up the total distance from the Point to the cluster centers, without taking into account the other clusters 

    '''
    # if not pokemon.loc[pokemon.isin(['weight_zscore', 'height_zscore', 'cluster'])].all():
    #      return
    metric = np.array([y['longitude'], y['latitude']])
    cluster_number = round(y['cluster'])
    distance = 0
    for cluster_index in range(0, len(cluster_centers)):
        if cluster_index != cluster_number :
            continue
        center = cluster_centers[cluster_index]         #longitude and latitude of the centroide in the cluster
        distance += np.sqrt(sum(np.square(metric - center)))
    return distance

# evaluate all chipotles
y_distance = y_clust.apply(distance_to_other_locations, axis=1)
y_distance = y_distance.rename('distance')

# join to other metrics
y_processed = y_clust.join(y_distance.to_frame())      #.join(y['name'].to_frame())

# pick most dissimilar chipotle per cluster
choosen_point = pd.DataFrame()
for cluster_index in range(0, len(cluster_centers)):
    y_cluster = y_processed[y_processed['cluster'] == cluster_index]
    choosen_point = choosen_point.append(y_cluster[y_cluster['distance']==y_cluster['distance'].min()])

# %%
# def distance_to_other_locations(y):   #using Eucledian distance 
    
#         for i in range(len(cluster_centers)):
#             metric = np.array([y_clust[y_clust['cluster']==i][['longitude','latitude']]])
#             distance = 0
#             for j in range (len(metric)): 
#                 metric_1 = np.delete(metric, j, axis=0)    #excluding the selected chepotle
#                 metric_2 = metric[j]
#                 distance += np.sqrt(sum(np.square(metric_1 - metric_2)))

#             return distance

# %%
choosen_point
# Out:
#        longitude   latitude  cluster  distance
# 1013  -89.704333  39.764472        0  0.723062
# 66   -111.979649  33.406421        1  0.023457
# 2583  -76.980441  38.846545        2  0.002979
# 136  -121.748850  37.961260        3  0.121979
# 850   -84.499298  33.657335        4  0.107726
# 2332  -96.962633  33.000507        5  0.047042
# 996   -87.827086  42.009979        6  0.012797
# 2574 -122.586663  45.653601        7  0.736360
# 790   -80.324485  26.149899        8  0.138189
# 582  -105.080898  39.660728        9  0.038391
# 1511  -74.362739  40.803468       10  0.012123
# 163  -117.719517  34.079562       11  0.006578
# 2421 -111.999468  41.178274       12  1.424432
# 1782  -80.563645  35.009226       13  0.703806
# 1979  -81.495850  41.448182       14  0.064380
# 1077  -95.251973  38.943178       15  0.278232
# 1878  -84.182595  39.741605       16  0.025900
# 1268  -71.591597  42.338815       17  0.110194
# 1363  -93.409948  44.924230       18  0.017834
# 2350  -98.095653  29.701030       19  0.060030
# 660   -81.730098  28.545699       20  0.249869
# 1574 -106.743618  32.314892       21  1.984956
# 2213  -94.977233  29.779715       22  0.239867
# 2169  -86.825243  35.945197       23  0.720007

# %%
len(choosen_point)
# Out:
# 24

# %%
# point with 
choosen_point.loc[choosen_point['distance'] == choosen_point['distance'].min()]
# Out:
#       longitude   latitude  cluster  distance
# 2583 -76.980441  38.846545        2  0.002979

# %%
# def AddPoint(plot, x, y, color):
#     plot.scatter(x, y, c=color)
#     plot.clf()
#     plot.show()

states.boundary.plot(figsize=(20,20))
g = sns.scatterplot(x='longitude', y='latitude', data=choosen_point_kmean, hue='cluster', s=300)
plt.scatter(-115.043449, 36.063149, c='red', s= 300)
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
plt.xlim([-130,-55])
plt.ylim([25,50])
plt.show()

# %%
predict = kmeans.fit_predict(y)
predict
# Out:
# array([13, 22, 22, ...,  8,  8,  1], dtype=int32)

# %%
# score the prediction of the clustering
km_silhouette_score = silhouette_score(y_clust, predict)
km_silhouette_score
# Out:
# 0.7238236104415042

# %%
#Sum of squared distances of samples to their closest cluster center.
kmeans_kwargs = {"init": "random",
                    "n_init": 10,
                     "max_iter": 300,
                      "random_state": 42,}

# A list holds the SSE values for each k
sum_sqrt_distance = []     # per cluster
for k in range(1, 30):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(y)
    sum_sqrt_distance.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10,10))
plt.style.use("fivethirtyeight")
plt.plot(range(1, 30), sum_sqrt_distance, 'ro-')
plt.xticks(range(1, 30))
plt.title('Selecting k with the Elbow Method')
plt.xlabel("Number of Clusters")
plt.ylabel("sum_sqrt_distance")
plt.show()

# %%
kl = KneeLocator(range(1, 30), sse, curve="convex", direction="decreasing")
kl.elbow
# Out:
# 4

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 30):
     kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
     kmeans.fit(y)
     score = silhouette_score(y, kmeans.labels_)
     silhouette_coefficients.append(score)

# %%
len(silhouette_coefficients)
# Out:
# 28

# %%
plt.figure(figsize=(8,6))
plt.style.use("fivethirtyeight")
plt.plot(range(2, 30), silhouette_coefficients)
plt.xticks(range(2, 30))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %% [markdown]
# ### Using KMeans with optimal n_clusters

# %%
#clustering using all the data
from sklearn.cluster import KMeans
# all the data 
y = df[['longitude','latitude']]
# fit a kmeans object to the dataset
km = KMeans(n_clusters=19, init='k-means++')
kmeans = km.fit(y)
# clusters is an attribute of the object
cluster_centers = kmeans.cluster_centers_

# add cluster to dataframe
cluster_labels = pd.Series(kmeans.labels_, name='cluster')
y_clust = y.join(cluster_labels.to_frame())

y_clust.head(10)
# Out:
#    longitude   latitude  cluster
# 0 -85.487328  32.606813       10
# 1 -86.802756  33.509721       10
# 2 -86.647437  33.595581       10
# 3 -86.698279  33.422582       10
# 4 -86.841220  34.154134       10
# 5 -86.803802  33.378958       10
# 6 -86.665720  34.742319       10
# 7 -88.143754  30.675338       10
# 8 -88.224998  30.682731       10
# 9 -86.162253  32.359177       10

# %%
predict = kmeans.fit_predict(y)
predict
# Out:
# array([12, 12, 12, ...,  0,  0,  8], dtype=int32)

# %%
# score the prediction of the clustering with the optimal n_clusters
km_silhouette_score = silhouette_score(y_clust, predict)
km_silhouette_score
# Out:
# 0.7021313410944304

# %% [markdown]
# ## Using DBscan

# %%
y_scan = df[['latitude', 'longitude']]
y_scan.head()
# Out:
#     latitude  longitude
# 0  32.606813 -85.487328
# 1  33.509721 -86.802756
# 2  33.595581 -86.647437
# 3  33.422582 -86.698279
# 4  34.154134 -86.841220

# %%
from sklearn.cluster import DBSCAN

# fit a DBSCAN to the dataset
dbscan = DBSCAN(eps=0.6, min_samples=2).fit(y_scan)

# add cluster index to dataframe
cluster_labels = pd.Series(dbscan.labels_, name='cluster')
dbscan_df = y_scan.join(cluster_labels.to_frame())

# %%
states.boundary.plot(figsize=(20,20))
g = sns.scatterplot(x='longitude', y='latitude', data=dbscan_df, hue='cluster', palette='husl')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
ax = plt.gca()
ax.set_title("Clusters with DBSCAN")
plt.xlim([-130,-50])
plt.ylim([25,50])
plt.show()

# sns.lmplot(x='longitude', y='latitude',  height=7, data=dbscan_df,
#            fit_reg=False, hue='cluster')
# ax = plt.gca()
# ax.set_title("Clusters with DBSCAN")

# %%
#prediction
predict = dbscan.fit_predict(y_scan)
predict
# Out:
# array([  0,   1,   1, ..., 105, 105,  -1])

# %%
# score the prediction of the clustering
dbscan_silhouette_score = silhouette_score(y_scan, predict)
dbscan_silhouette_score
# Out:
# 0.34784224756870086

# %%
dbscan_df['cluster'].value_counts()[:40]
# Out:
#  18     492
#  13     251
#  35     234
#  20     165
#  12     155
#  29     153
#  88      91
#  17      77
#  50      73
#  5       64
#  53      64
# -1       62
#  70      61
#  90      60
#  24      51
#  89      46
#  43      42
#  101     35
#  75      32
#  78      25
#  62      24
#  36      21
#  99      17
#  86      13
#  33      12
#  7       12
#  96      10
#  65       9
#  64       8
#  52       7
#  42       7
#  15       7
#  60       7
#  69       7
#  66       6
#  16       6
#  1        6
#  73       6
#  87       6
#  26       5
# Name: cluster, dtype: int64

# %% [markdown]
# ## Using Optics

# %%
from sklearn.cluster import OPTICS

X = df.loc[:,['longitude','latitude']]
optics = OPTICS(min_samples=50).fit(X)

# %%
optics.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, 14])

# %%
# add cluster index to dataframe
cluster_labels_opt = pd.Series(optics.labels_, name='cluster')
optics_df = X.join(cluster_labels_opt.to_frame())

# %%
optics_df['cluster'].value_counts()[:20]
# Out:
# -1     598
#  16    274
#  3     186
#  1     183
#  7     178
#  17    150
#  14     97
#  9      95
#  12     94
#  15     85
#  4      77
#  5      76
#  11     76
#  8      74
#  0      72
#  18     70
#  10     63
#  6      63
#  13     63
#  2      55
# Name: cluster, dtype: int64

# %%
len(optics_df['cluster'].value_counts())
# Out:
# 20

# %%
states.boundary.plot(figsize=(20,20))
g = sns.scatterplot(x='longitude', y='latitude', data=optics_df, hue='cluster', palette='husl')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
ax = plt.gca()
ax.set_title("Clusters with OPTICS")
plt.xlim([-130,-50])
plt.ylim([25,50])
plt.show()

# %%
#prediction
predict = optics.fit_predict(y_scan)
predict
# Out:
# array([-1, -1, -1, ..., -1, -1, 14])

# %%
# score the prediction of the clustering
dbscan_silhouette_score = silhouette_score(X, predict)
dbscan_silhouette_score
# Out:
# 0.41194073837259354
